# %% [markdown]
# 1. Welcome
# 2. Name of the trains
# 3. Quota
# 4. Status(seat, price)
# 5. Book Ticket
# 6. Cancel Ticket
# 7. Tatkal Ticket

# %%
pip install sys

# %%
import sys
print("Welcome to IRCTC App")

ask =input("Do you want to 'Book' or 'Cancel' your ticket? ")
ask1 = ask.upper()

def cancelTicket():
    input("Type your PNR number: ")
    print("----------------------------------------------------------------")
    print("Your ticket has been cancelled")
    print("Your amount will be refunded within 72 hours after deducting charges")
    sys.exit()
    
if ask1=="CANCEL":
    cancelTicket()
    
print("***Name of trains***")
    
trainList = ["1.Rajdhani Express", "2.Satabdi Express", "3.Vande Bharat Express", "4.Superfast Express", "5.Jammu Tavi Express"]

for i in trainList:
    print(i)
    
trainNo = int(input("Please select your train number from the following list: "))

if trainNo==1:
    print("You have seleted: Rajdhani Express")
elif trainNo==2:
    print("You have seleted: Local")
elif trainNo==3:
    print("You have seleted: Vande Bharat Express")
elif trainNo==4:
    print("You have seleted: Superfast Express")
elif trainNo==5:
    print("You have seleted: Jammu Tavi Express")
else:
    print("Please provide valid input")
print("----------------------------------------------------------------")

print("***Quota***")    
quotaList = ["1.General", "2.Tatkal"]

for i in quotaList:
    print(i)

quota = int(input("Please select your Quota from the following list: "))

if quota==1:
    print("You have seleted: General")
elif quota==2:
    print("You have seleted: Tatkal")
else:
    print("Please provide valid input")
    
def status(seat, price):
    print("Seat available:",seat)
    print("Price per person:",price)

if trainNo==1 and quota==1:
    price = 2000
    seat = 100
elif trainNo==2 and quota==1:
    price = 2500
    seat = 150
elif trainNo==3 and quota==1:
    price = 3000
    seat = 200
elif trainNo==4 and quota==1:
    price = 500
    seat = 250
elif trainNo==5 and quota==1:
    price = 300
    seat = 300
elif trainNo==1 and quota==2:
    price = 2800
    seat = 50
elif trainNo==2 and quota==2:
    price = 3500
    seat = 60
elif trainNo==3 and quota==2:
    price = 4200
    seat = 70
elif trainNo==4 and quota==2:
    price = 800
    seat = 80
elif trainNo==5 and quota==2:
    price = 450
    seat = 90
else:
    print("Please provide valid input")
print("----------------------------------------------------------------")
    
status(seat, price)
print("----------------------------------------------------------------")

ticket = input("Do you want to book your ticket? Yes or No:\n")
ticket1 = ticket.upper()

def bookTicket():
    print("Name:",name)
    print("Age:",age)
    print("Seat Number:",seat)

if ticket1=="YES":
    if seat>0:
        count=0
        noOfPassenger = int(input("For how many passenger do you want to book tickets-Enter number only: "))
        print("Total amount=",price*noOfPassenger)
        while noOfPassenger>=1:
            name = input("Enter the name: ")
            age = int(input("Enter the age: "))
            noOfPassenger-=1
            print("Your ticket has been booked")
            print("----------------------------------------------------------------")
            bookTicket()
            seat -=1
            print("----------------------------------------------------------------")
    else:
         print("Sorry this train is full! Kindly try in tatkal")
elif ticket1=="NO":
    print("Thank You visit again")
else:
    print("Please provide valid input")
